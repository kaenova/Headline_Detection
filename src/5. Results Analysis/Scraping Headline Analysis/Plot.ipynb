# %%
# Indonesia

import matplotlib.pyplot as plt
import numpy as np

crawl_topics = ("Efektif", "Gratis", "Moderna", "Pfizer")
penguin_means = {
    'Headline': (round(0.7316504854368931, 2), 
                 round(0.6526558481865744, 2),
                 round(0.7604943532921372, 2),
                 round(0.7669474528680305, 2)),
    'Non-Headline': (1 - round(0.7316504854368931, 2), 
                     1 - round(0.6526558481865744, 2),
                     1 - round(0.7604943532921372, 2),
                     1 - round(0.7669474528680305, 2)),
}

x = np.arange(len(crawl_topics))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

colors = ['#d62728', '#bcbd22', '#d62728', '#bcbd22']

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute,  color=colors[multiplier])
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Rasio')
ax.set_xlabel('Topik')
ax.set_title('Rasio Headline pada Pengambilan Data Twitter')
ax.set_xticks(x + width - 0.135, crawl_topics)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1)
plt.savefig('Scraping Indonesia.svg', format='svg')
plt.show()

# %%
# English

import matplotlib.pyplot as plt
import numpy as np

crawl_topics = ("Efektif", "Gratis", "Moderna", "Pfizer")
penguin_means = {
    'Headline': (round(0.7316504854368931, 2), 
                 round(0.6526558481865744, 2),
                 round(0.7604943532921372, 2),
                 round(0.7669474528680305, 2)),
    'Non-Headline': (1 - round(0.7316504854368931, 2), 
                     1 - round(0.6526558481865744, 2),
                     1 - round(0.7604943532921372, 2),
                     1 - round(0.7669474528680305, 2)),
}

x = np.arange(len(crawl_topics))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

colors = ['#d62728', '#bcbd22', '#d62728', '#bcbd22']

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute,  color=colors[multiplier])
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Topic')
ax.set_ylabel('Ratio')
ax.set_title('Headline Ratio on Crawled Twitter Data')
ax.set_xticks(x + width - 0.135, crawl_topics)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 1)

plt.savefig('Scraping English.svg', format='svg')
plt.show()
