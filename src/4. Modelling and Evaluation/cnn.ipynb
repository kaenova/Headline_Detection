# %%
# # Prepare Google Colab Environement and build handmade library
# !git clone https://github.com/kaenova/Headline_Detection.git
# %cd "/content/Headline_Detection"

# !make lib

# %cd "/content/"

# print("Please upload '4. Processed.zip'")
# from google.colab import files
# files.upload()

# !unzip "/content/4. Processed.zip"

# print("Please upload .env")
# from google.colab import files
# files.upload()

# %%
# # Reset Google Colab Environment
# %cd "/content/"
# !rm -fr Headline_Detection

# %% [markdown]
# # Load Config and Env

# %%
# Load env for S3 uploads
from dotenv import load_dotenv
from kaelib.s3 import check_required_env_vars
import os
load_dotenv()
check_required_env_vars()

# %% [markdown]
# # Load Dataset

# %%
import os
import pandas as pd

environment = 'local'
if environment == 'local':
    data_path = "../../data/4. Processed/"
elif environment == 'colab':
    data_path = "/content/4. Processed/"
else:
    raise ImportError("Data environment")


folders = os.listdir(data_path)
scenario_data = {}

for folder in folders:
    current_data_path = f"{data_path}/{folder}"
    if not os.path.isdir(current_data_path):
        continue
    files = os.listdir(current_data_path)
    data_dict = {}
    for file in files:
        current_file = f"{current_data_path}/{file}"
        data_dict[file] = pd.read_csv(current_file)
    scenario_data[int(folder)] = data_dict

# %%
import torch
import pandas
import typing
from torch.utils.data import Dataset
from kaelib.processor import TextProcessingPipeline


class TextClassificationDataset(Dataset):
    def __init__(
        self,
        df: "pandas.DataFrame",
        x_column_name: "str" = "tweet",
        y_column_name: "str" = "labels",
        preprocessor: "typing.Optional[TextProcessingPipeline]" = None,
    ):
        self.x = df[x_column_name].astype(str).to_list()
        self.y = torch.tensor(df[y_column_name].astype(int).to_list())
        assert len(self.x) == len(self.y)
        self.preprocessor = preprocessor

    def __len__(self):
        return len(self.x)

    def _process_idx_text(self, idx):
        data = self.x[idx]
        if type(idx) is not slice:
            data = [self.x[idx]]
        if self.preprocessor is not None:
            data = self.preprocessor.process_corpus(data)
        return data

    def __getitem__(self, idx):
        processed_corpus = self._process_idx_text(idx)
        return processed_corpus, self.y[idx]

    def __repr__(self) -> str:
        return "\n".join([f"{self.x[i]} : {self.y[i]}" for i in range(5)])


scenario_datasets = {}
for scenario in scenario_data:
    data = scenario_data[scenario]
    datasets = {}
    for data_type in data:
        datasets[data_type] = TextClassificationDataset(data[data_type])
    scenario_datasets[scenario] = datasets

# %% [markdown]
# # Modelling

# %%
# Hyperparameters
hyper_params = {
    'seq_length': 256,
    'out_feature': 2,
    'learning_rate': 1e-3,
    'batch_size': 16,
    'conv_num_filters': 100,
    'conv_kernels': (1,2,3)
}

# %%
# https://ieeexplore.ieee.org/document/8577620
# https://ieeexplore.ieee.org/abstract/document/8589431
# https://ieeexplore.ieee.org/document/8691381
# https://aclanthology.org/D14-1181.pdf

import math
import torch
import torch.nn as nn
import torchnlp.nn as nnlp
import lightning.pytorch as pl
import torch.nn.functional as F

from torch.optim.lr_scheduler import ExponentialLR
from torchnlp.word_to_vector import FastText
from torchmetrics.classification import F1Score, Accuracy, Recall, Precision

class CNNClassifier(pl.LightningModule):
    def __init__(
        self,
        seq_length: "int",
        out_feature: "int",
        fast_text_lang: 'str' = 'id',
        fast_text_pad_sequence: 'bool' = True,
        conv_num_filters: int = 100, 
        conv_kernels: "tuple[int]" = (3,4,5),
        feed_forward_dropout: 'float' = 0.5,
    ) -> None:
        super().__init__()

        # Config
        self.seq_length = seq_length
        self.fast_text_pad_sequence = fast_text_pad_sequence
        
        # Layer
        self.fasttext = FastText(fast_text_lang)

        self.conv_layer = nnlp.CNNEncoder(300, conv_num_filters, conv_kernels)
        
        self.classification_head = nn.Sequential(
            nn.Dropout(feed_forward_dropout),
            nn.Linear(len(conv_kernels) * conv_num_filters, out_feature),
        )

        # Scorer
        self.f1_scorer = F1Score(task="multiclass", num_classes=out_feature)
        self.accuracy_scorer = Accuracy(task="multiclass", num_classes=out_feature)
        self.precision_scorer = Precision(task="multiclass", num_classes=out_feature)
        self.recall_scorer = Recall(task="multiclass", num_classes=out_feature)

    def _forward_fasttext(self, x: "list[str]"):
        batch_text_embedding = torch.tensor([]).to(self.device)
        for sentence in x:
            sentence_seq = sentence.split(" ")
            if len(sentence_seq) > self.seq_length:
                sentence_seq = sentence_seq[: self.seq_length]
            if self.fast_text_pad_sequence:
                while len(sentence_seq) < 256:
                    sentence_seq.append("<PAD>")
            word_embedding = (
                self.fasttext[sentence_seq].unsqueeze(0).to(self.device)
            )
            batch_text_embedding = torch.cat((batch_text_embedding, word_embedding))
        return batch_text_embedding

    def forward(self, x: "list[str]"):
        x = self._forward_fasttext(x)
        x = self.conv_layer(x)
        x = self.classification_head(x)

        return x

    def training_step(self, batch, batch_idx):
        # training_step defines the train loop.
        x, y = batch
        pred = self.forward(x[0])
        loss = F.cross_entropy(pred, y)
        self.log("training_loss", loss, prog_bar=True)
        f1_score = self.f1_scorer(pred, y)
        self.log("training_f1", f1_score, prog_bar=True)
        accuracy = self.accuracy_scorer(pred, y)
        self.log("training_accuracy", accuracy, prog_bar=True)
        return loss

    def validation_step(self, batch, batch_idx):
        # training_step defines the train loop.
        x, y = batch
        pred = self.forward(x[0])
        loss = F.cross_entropy(pred, y)
        self.log("validation_loss", loss, prog_bar=True)
        f1_score = self.f1_scorer(pred, y)
        self.log("validation_f1", f1_score, prog_bar=True)
        accuracy = self.accuracy_scorer(pred, y)
        self.log("validation_accuracy", accuracy, prog_bar=True)
        precision = self.precision_scorer(pred, y)
        self.log("validation_precision", precision, prog_bar=True)
        recall = self.recall_scorer(pred, y)
        self.log("validation_recall", recall, prog_bar=True)

    def test_step(self, batch, batch_idx):
        # training_step defines the train loop.
        x, y = batch
        pred = self.forward(x[0])
        loss = F.cross_entropy(pred, y)
        self.log("test_loss", loss)
        f1_score = self.f1_scorer(pred, y)
        self.log("test_f1", f1_score, prog_bar=True)
        accuracy = self.accuracy_scorer(pred, y)
        self.log("test_accuracy", accuracy, prog_bar=True)
        precision = self.precision_scorer(pred, y)
        self.log("test_precision", precision, prog_bar=True)
        recall = self.recall_scorer(pred, y)
        self.log("test_recall", recall, prog_bar=True)

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=hyper_params['learning_rate'])
        return optimizer

# %%
model_module = CNNClassifier
def create_model():
    return model_module(hyper_params['seq_length'], hyper_params['out_feature'], conv_num_filters=hyper_params['conv_num_filters'], conv_kernels=hyper_params['conv_kernels'])

def load_model(path):
    return model_module.load_from_checkpoint(path, seq_length=hyper_params['seq_length'], out_feature=hyper_params['out_feature'], conv_num_filters=hyper_params['conv_num_filters'], conv_kernels=hyper_params['conv_kernels'])

# %%
model = create_model()
model(['hello my name', 'hello are you']).shape
# Out:
# torch.Size([2, 2])

# %% [markdown]
# # Train, Val, Test

# %%
available_cpus = 0
model_name = "cnn"
tuning = False

# %%
import datetime
import random
import torch
import numpy as np

from torch.utils.data import DataLoader
from lightning.pytorch.loggers import TensorBoardLogger
from lightning.pytorch.callbacks.early_stopping import EarlyStopping
from lightning.pytorch.callbacks import ModelCheckpoint

now = datetime.datetime.now()
timestamp = now.strftime('%Y-%m-%d_%H-%M-%S')

for scenario in scenario_datasets:
    np.random.seed(2023)
    random.seed(2023)
    torch.manual_seed(2023)

    run_id = f"{timestamp}_scenario_{scenario}"

    if scenario in [0]:
        continue

    if tuning:
        if scenario in [2,3,4,5,6]:
            continue
        run_id += "_tuning"

    model = create_model()

    # Dataset
    train_dataset = scenario_datasets[scenario]["train.csv"]
    test_dataset = scenario_datasets[scenario]["test.csv"]
    # validation_dataset = scenario_datasets[scenario]["validation.csv"]
    train_loader = DataLoader(train_dataset, batch_size=hyper_params['batch_size'], num_workers=available_cpus)
    # validation_loader = DataLoader(validation_dataset, batch_size=hyper_params['batch_size'], num_workers=available_cpus)
    test_loader = DataLoader(test_dataset, batch_size=hyper_params['batch_size'], num_workers=available_cpus)

    tb_log = TensorBoardLogger("tensorboard", model_name, run_id)

    checkpoint_callback_val = ModelCheckpoint(monitor="validation_loss", filename='val_{epoch}-{validation_loss:.4f}')
    checkpoint_callback_train = ModelCheckpoint(monitor="training_loss", filename='train_{epoch}-{training_loss:.4f}')
    early_stop_callback = EarlyStopping(
        monitor="validation_loss", min_delta=1e-3, patience=5, mode="min"
    )

    trainer = pl.Trainer(
        logger=tb_log,
        log_every_n_steps=2, 
        callbacks=[early_stop_callback, checkpoint_callback_val, checkpoint_callback_train]
    )
    print(run_id)
    trainer.fit(
        model=model, train_dataloaders=train_loader, val_dataloaders=test_loader
    )
    model = load_model(checkpoint_callback_val.best_model_path)
    test_metric = trainer.test(model=model, dataloaders=test_loader)[0]['test_loss']
    tb_log.log_hyperparams(hyper_params, {'hp_metric': test_metric})
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                | Type                | Params
# ------------------------------------------------------------
# 0 | conv_layer          | CNNEncoder          | 180 K
# 1 | classification_head | Sequential          | 602
# 2 | f1_scorer           | MulticlassF1Score   | 0
# 3 | accuracy_scorer     | MulticlassAccuracy  | 0
# 4 | precision_scorer    | MulticlassPrecision | 0
# 5 | recall_scorer       | MulticlassRecall    | 0
# ------------------------------------------------------------
# 180 K     Trainable params
# 0         Non-trainable params
# 180 K     Total params
# 0.724     Total estimated model params size (MB)
# 2023-04-25_09-07-51_scenario_6
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │    0.8897637724876404     │
# │          test_f1          │    0.8897637724876404     │
# │         test_loss         │    0.28070777654647827    │
# │      test_precision       │    0.8897637724876404     │
# │        test_recall        │    0.8897637724876404     │
# └───────────────────────────┴───────────────────────────┘
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                | Type                | Params
# ------------------------------------------------------------
# 0 | conv_layer          | CNNEncoder          | 180 K
# 1 | classification_head | Sequential          | 602
# 2 | f1_scorer           | MulticlassF1Score   | 0
# 3 | accuracy_scorer     | MulticlassAccuracy  | 0
# 4 | precision_scorer    | MulticlassPrecision | 0
# 5 | recall_scorer       | MulticlassRecall    | 0
# ------------------------------------------------------------
# 180 K     Trainable params
# 0         Non-trainable params
# 180 K     Total params
# 0.724     Total estimated model params size (MB)
# 2023-04-25_09-07-51_scenario_2
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │    0.9081364870071411     │
# │          test_f1          │    0.9081364870071411     │
# │         test_loss         │    0.22219893336296082    │
# │      test_precision       │    0.9081364870071411     │
# │        test_recall        │    0.9081364870071411     │
# └───────────────────────────┴───────────────────────────┘
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                | Type                | Params
# ------------------------------------------------------------
# 0 | conv_layer          | CNNEncoder          | 180 K
# 1 | classification_head | Sequential          | 602
# 2 | f1_scorer           | MulticlassF1Score   | 0
# 3 | accuracy_scorer     | MulticlassAccuracy  | 0
# 4 | precision_scorer    | MulticlassPrecision | 0
# 5 | recall_scorer       | MulticlassRecall    | 0
# ------------------------------------------------------------
# 180 K     Trainable params
# 0         Non-trainable params
# 180 K     Total params
# 0.724     Total estimated model params size (MB)
# 2023-04-25_09-07-51_scenario_4
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │    0.8897637724876404     │
# │          test_f1          │    0.8897637724876404     │
# │         test_loss         │    0.2821679413318634     │
# │      test_precision       │    0.8897637724876404     │
# │        test_recall        │    0.8897637724876404     │
# └───────────────────────────┴───────────────────────────┘
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                | Type                | Params
# ------------------------------------------------------------
# 0 | conv_layer          | CNNEncoder          | 180 K
# 1 | classification_head | Sequential          | 602
# 2 | f1_scorer           | MulticlassF1Score   | 0
# 3 | accuracy_scorer     | MulticlassAccuracy  | 0
# 4 | precision_scorer    | MulticlassPrecision | 0
# 5 | recall_scorer       | MulticlassRecall    | 0
# ------------------------------------------------------------
# 180 K     Trainable params
# 0         Non-trainable params
# 180 K     Total params
# 0.724     Total estimated model params size (MB)
# 2023-04-25_09-07-51_scenario_3
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │    0.8950130939483643     │
# │          test_f1          │    0.8950130939483643     │
# │         test_loss         │    0.2586827874183655     │
# │      test_precision       │    0.8950130939483643     │
# │        test_recall        │    0.8950130939483643     │
# └───────────────────────────┴───────────────────────────┘
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                | Type                | Params
# ------------------------------------------------------------
# 0 | conv_layer          | CNNEncoder          | 180 K
# 1 | classification_head | Sequential          | 602
# 2 | f1_scorer           | MulticlassF1Score   | 0
# 3 | accuracy_scorer     | MulticlassAccuracy  | 0
# 4 | precision_scorer    | MulticlassPrecision | 0
# 5 | recall_scorer       | MulticlassRecall    | 0
# ------------------------------------------------------------
# 180 K     Trainable params
# 0         Non-trainable params
# 180 K     Total params
# 0.724     Total estimated model params size (MB)
# 2023-04-25_09-07-51_scenario_1
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │    0.9081364870071411     │
# │          test_f1          │    0.9081364870071411     │
# │         test_loss         │    0.22597379982471466    │
# │      test_precision       │    0.9081364870071411     │
# │        test_recall        │    0.9081364870071411     │
# └───────────────────────────┴───────────────────────────┘
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                | Type                | Params
# ------------------------------------------------------------
# 0 | conv_layer          | CNNEncoder          | 180 K
# 1 | classification_head | Sequential          | 602
# 2 | f1_scorer           | MulticlassF1Score   | 0
# 3 | accuracy_scorer     | MulticlassAccuracy  | 0
# 4 | precision_scorer    | MulticlassPrecision | 0
# 5 | recall_scorer       | MulticlassRecall    | 0
# ------------------------------------------------------------
# 180 K     Trainable params
# 0         Non-trainable params
# 180 K     Total params
# 0.724     Total estimated model params size (MB)
# 2023-04-25_09-07-51_scenario_5
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │    0.8950130939483643     │
# │          test_f1          │    0.8950130939483643     │
# │         test_loss         │    0.2576427161693573     │
# │      test_precision       │    0.8950130939483643     │
# │        test_recall        │    0.8950130939483643     │
# └───────────────────────────┴───────────────────────────┘

# %% [markdown]
# # Upload Logging and Checkpoint to S3

# %%
import os
from kaelib.s3_threading import upload_folder_to_s3_all_threads
s3_folders = os.path.join(os.getenv("BUCKET_FOLDER"), model_name)
upload_folder_to_s3_all_threads(f"tensorboard/{model_name}", s3_folders)
# Out:
# Uploading:   0%|                                      | 0/96 [00:00<?, ?false/s]
# Uploading:   0%| | 0/96 [00:08<?, ?false/s, file=Log and Checkpoints/2023_04_21/
# Uploading:   1%| | 1/96 [00:08<13:34,  8.57s/false, file=Log and Checkpoints/202
# Uploading:   1%| | 1/96 [00:08<13:34,  8.57s/false, file=Log and Checkpoints/202
# Uploading:   2%| | 2/96 [00:08<13:25,  8.57s/false, file=Log and Checkpoints/202
# Uploading:   3%| | 3/96 [00:08<03:30,  2.27s/false, file=Log and Checkpoints/202
# Uploading:   3%| | 3/96 [00:08<03:30,  2.27s/false, file=Log and Checkpoints/202
# Uploading:   4%| | 4/96 [00:08<03:28,  2.27s/false, file=Log and Checkpoints/202
# Uploading:   5%| | 5/96 [00:08<03:26,  2.27s/false, file=Log and Checkpoints/202
# Uploading:   6%| | 6/96 [00:08<03:24,  2.27s/false, file=Log and Checkpoints/202
# Uploading:   7%| | 7/96 [00:08<01:07,  1.33false/s, file=Log and Checkpoints/202
# Uploading:   7%| | 7/96 [00:09<01:07,  1.33false/s, file=Log and Checkpoints/202
# Uploading:   8%| | 8/96 [00:09<01:06,  1.33false/s, file=Log and Checkpoints/202
# Uploading:   9%| | 9/96 [00:09<00:49,  1.77false/s, file=Log and Checkpoints/202
# Uploading:   9%| | 9/96 [00:09<00:49,  1.77false/s, file=Log and Checkpoints/202
# Uploading:  10%| | 10/96 [00:09<00:48,  1.77false/s, file=Log and Checkpoints/20
# Uploading:  11%| | 11/96 [00:09<00:48,  1.77false/s, file=Log and Checkpoints/20
# Uploading:  12%|▏| 12/96 [00:09<00:29,  2.86false/s, file=Log and Checkpoints/20
# Uploading:  14%|▏| 13/96 [00:09<00:17,  4.75false/s, file=Log and Checkpoints/20
# Uploading:  14%|▏| 13/96 [00:09<00:17,  4.75false/s, file=Log and Checkpoints/20
# Uploading:  14%|▏| 13/96 [00:09<00:17,  4.75false/s, file=Log and Checkpoints/20
# Uploading:  15%|▏| 14/96 [00:09<00:17,  4.75false/s, file=Log and Checkpoints/20
# Uploading:  16%|▏| 15/96 [00:09<00:17,  4.75false/s, file=Log and Checkpoints/20
# Uploading:  17%|▏| 16/96 [00:09<00:16,  4.75false/s, file=Log and Checkpoints/20
# Uploading:  18%|▏| 17/96 [00:09<00:16,  4.75false/s, file=Log and Checkpoints/20
# Uploading:  19%|▏| 18/96 [00:09<00:16,  4.75false/s, file=Log and Checkpoints/20
# Uploading:  20%|▏| 19/96 [00:09<00:09,  8.55false/s, file=Log and Checkpoints/20
# Uploading:  20%|▏| 19/96 [00:09<00:09,  8.55false/s, file=Log and Checkpoints/20
# Uploading:  21%|▏| 20/96 [00:09<00:08,  8.55false/s, file=Log and Checkpoints/20
# Uploading:  22%|▏| 21/96 [00:09<00:08,  8.55false/s, file=Log and Checkpoints/20
# Uploading:  23%|▏| 22/96 [00:09<00:08,  8.55false/s, file=Log and Checkpoints/20
# Uploading:  24%|▏| 23/96 [00:09<00:08,  8.55false/s, file=Log and Checkpoints/20
# Uploading:  25%|▎| 24/96 [00:09<00:08,  8.55false/s, file=Log and Checkpoints/20
# Uploading:  26%|▎| 25/96 [00:09<00:08,  8.55false/s, file=Log and Checkpoints/20
# Uploading:  27%|▎| 26/96 [00:09<00:05, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  27%|▎| 26/96 [00:09<00:05, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  28%|▎| 27/96 [00:09<00:05, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  29%|▎| 28/96 [00:09<00:04, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  30%|▎| 29/96 [00:09<00:04, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  31%|▎| 30/96 [00:09<00:04, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  32%|▎| 31/96 [00:09<00:04, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  33%|▎| 32/96 [00:09<00:04, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  34%|▎| 33/96 [00:09<00:04, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  35%|▎| 34/96 [00:09<00:04, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  36%|▎| 35/96 [00:09<00:04, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  38%|▍| 36/96 [00:09<00:04, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  39%|▍| 37/96 [00:09<00:04, 13.69false/s, file=Log and Checkpoints/20
# Uploading:  40%|▍| 38/96 [00:09<00:02, 24.57false/s, file=Log and Checkpoints/20
# Uploading:  40%|▍| 38/96 [00:09<00:02, 24.57false/s, file=Log and Checkpoints/20
# Uploading:  41%|▍| 39/96 [00:09<00:02, 24.57false/s, file=Log and Checkpoints/20
# Uploading:  42%|▍| 40/96 [00:09<00:02, 24.57false/s, file=Log and Checkpoints/20
# Uploading:  43%|▍| 41/96 [00:09<00:02, 24.57false/s, file=Log and Checkpoints/20
# Uploading:  44%|▍| 42/96 [00:09<00:02, 24.57false/s, file=Log and Checkpoints/20
# Uploading:  45%|▍| 43/96 [00:09<00:02, 24.57false/s, file=Log and Checkpoints/20
# Uploading:  46%|▍| 44/96 [00:09<00:01, 27.88false/s, file=Log and Checkpoints/20
# Uploading:  46%|▍| 44/96 [00:09<00:01, 27.88false/s, file=Log and Checkpoints/20
# Uploading:  47%|▍| 45/96 [00:09<00:01, 27.88false/s, file=Log and Checkpoints/20
# Uploading:  48%|▍| 46/96 [00:09<00:01, 27.88false/s, file=Log and Checkpoints/20
# Uploading:  49%|▍| 47/96 [00:09<00:01, 27.88false/s, file=Log and Checkpoints/20
# Uploading:  50%|▌| 48/96 [00:09<00:01, 27.88false/s, file=Log and Checkpoints/20
# Uploading:  51%|▌| 49/96 [00:10<00:01, 27.88false/s, file=Log and Checkpoints/20
# Uploading:  52%|▌| 50/96 [00:10<00:01, 28.73false/s, file=Log and Checkpoints/20
# Uploading:  52%|▌| 50/96 [00:11<00:01, 28.73false/s, file=Log and Checkpoints/20
# Uploading:  53%|▌| 51/96 [00:11<00:01, 28.73false/s, file=Log and Checkpoints/20
# Uploading:  54%|▌| 52/96 [00:11<00:01, 28.73false/s, file=Log and Checkpoints/20
# Uploading:  55%|▌| 53/96 [00:11<00:01, 28.73false/s, file=Log and Checkpoints/20
# Uploading:  56%|▌| 54/96 [00:11<00:01, 28.73false/s, file=Log and Checkpoints/20
# Uploading:  57%|▌| 55/96 [00:11<00:03, 10.49false/s, file=Log and Checkpoints/20
# Uploading:  57%|▌| 55/96 [00:11<00:03, 10.49false/s, file=Log and Checkpoints/20
# Uploading:  58%|▌| 56/96 [00:11<00:03, 10.49false/s, file=Log and Checkpoints/20
# Uploading:  59%|▌| 57/96 [00:11<00:03, 10.49false/s, file=Log and Checkpoints/20
# Uploading:  60%|▌| 58/96 [00:12<00:03, 10.49false/s, file=Log and Checkpoints/20
# Uploading:  61%|▌| 59/96 [00:12<00:04,  8.71false/s, file=Log and Checkpoints/20
# Uploading:  62%|▋| 60/96 [00:12<00:04,  8.08false/s, file=Log and Checkpoints/20
# Uploading:  62%|▋| 60/96 [00:12<00:04,  8.08false/s, file=Log and Checkpoints/20
# Uploading:  62%|▋| 60/96 [00:12<00:04,  8.08false/s, file=Log and Checkpoints/20
# Uploading:  64%|▋| 61/96 [00:12<00:04,  8.08false/s, file=Log and Checkpoints/20
# Uploading:  65%|▋| 62/96 [00:12<00:04,  8.13false/s, file=Log and Checkpoints/20
# Uploading:  65%|▋| 62/96 [00:13<00:04,  8.13false/s, file=Log and Checkpoints/20
# Uploading:  66%|▋| 63/96 [00:14<00:04,  8.13false/s, file=Log and Checkpoints/20
# Uploading:  67%|▋| 64/96 [00:14<00:07,  4.19false/s, file=Log and Checkpoints/20
# Uploading:  67%|▋| 64/96 [00:26<00:07,  4.19false/s, file=Log and Checkpoints/20
# Uploading:  68%|▋| 65/96 [00:27<00:07,  4.19false/s, file=Log and Checkpoints/20
# Uploading:  69%|▋| 66/96 [00:27<00:43,  1.45s/false, file=Log and Checkpoints/20
# Uploading:  69%|▋| 66/96 [00:31<00:43,  1.45s/false, file=Log and Checkpoints/20
# Uploading:  70%|▋| 67/96 [00:31<00:50,  1.75s/false, file=Log and Checkpoints/20
# Uploading:  70%|▋| 67/96 [00:31<00:50,  1.75s/false, file=Log and Checkpoints/20
# Uploading:  71%|▋| 68/96 [00:31<00:44,  1.58s/false, file=Log and Checkpoints/20
# Uploading:  71%|▋| 68/96 [00:34<00:44,  1.58s/false, file=Log and Checkpoints/20
# Uploading:  72%|▋| 69/96 [00:34<00:50,  1.86s/false, file=Log and Checkpoints/20
# Uploading:  72%|▋| 69/96 [00:36<00:50,  1.86s/false, file=Log and Checkpoints/20
# Uploading:  73%|▋| 70/96 [00:36<00:47,  1.81s/false, file=Log and Checkpoints/20
# Uploading:  73%|▋| 70/96 [00:37<00:47,  1.81s/false, file=Log and Checkpoints/20
# Uploading:  74%|▋| 71/96 [00:37<00:41,  1.68s/false, file=Log and Checkpoints/20
# Uploading:  74%|▋| 71/96 [00:37<00:41,  1.68s/false, file=Log and Checkpoints/20
# Uploading:  75%|▊| 72/96 [00:37<00:40,  1.68s/false, file=Log and Checkpoints/20
# Uploading:  76%|▊| 73/96 [00:37<00:24,  1.05s/false, file=Log and Checkpoints/20
# Uploading:  76%|▊| 73/96 [00:38<00:24,  1.05s/false, file=Log and Checkpoints/20
# Uploading:  77%|▊| 74/96 [00:38<00:23,  1.07s/false, file=Log and Checkpoints/20
# Uploading:  77%|▊| 74/96 [00:39<00:23,  1.07s/false, file=Log and Checkpoints/20
# Uploading:  78%|▊| 75/96 [00:40<00:22,  1.07s/false, file=Log and Checkpoints/20
# Uploading:  79%|▊| 76/96 [00:40<00:19,  1.02false/s, file=Log and Checkpoints/20
# Uploading:  79%|▊| 76/96 [00:40<00:19,  1.02false/s, file=Log and Checkpoints/20
# Uploading:  80%|▊| 77/96 [00:40<00:18,  1.02false/s, file=Log and Checkpoints/20
# Uploading:  81%|▊| 78/96 [00:40<00:17,  1.02false/s, file=Log and Checkpoints/20
# Uploading:  82%|▊| 79/96 [00:40<00:09,  1.79false/s, file=Log and Checkpoints/20
# Uploading:  82%|▊| 79/96 [00:40<00:09,  1.79false/s, file=Log and Checkpoints/20
# Uploading:  83%|▊| 80/96 [00:40<00:08,  1.79false/s, file=Log and Checkpoints/20
# Uploading:  84%|▊| 81/96 [00:40<00:06,  2.42false/s, file=Log and Checkpoints/20
# Uploading:  84%|▊| 81/96 [00:41<00:06,  2.42false/s, file=Log and Checkpoints/20
# Uploading:  85%|▊| 82/96 [00:41<00:05,  2.42false/s, file=Log and Checkpoints/20
# Uploading:  86%|▊| 83/96 [00:41<00:04,  2.77false/s, file=Log and Checkpoints/20
# Uploading:  86%|▊| 83/96 [00:41<00:04,  2.77false/s, file=Log and Checkpoints/20
# Uploading:  88%|▉| 84/96 [00:41<00:04,  2.82false/s, file=Log and Checkpoints/20
# Uploading:  88%|▉| 84/96 [00:42<00:04,  2.82false/s, file=Log and Checkpoints/20
# Uploading:  89%|▉| 85/96 [00:42<00:04,  2.66false/s, file=Log and Checkpoints/20
# Uploading:  89%|▉| 85/96 [00:42<00:04,  2.66false/s, file=Log and Checkpoints/20
# Uploading:  90%|▉| 86/96 [00:42<00:04,  2.23false/s, file=Log and Checkpoints/20
# Uploading:  90%|▉| 86/96 [00:43<00:04,  2.23false/s, file=Log and Checkpoints/20
# Uploading:  91%|▉| 87/96 [00:43<00:03,  2.45false/s, file=Log and Checkpoints/20
# Uploading:  91%|▉| 87/96 [00:45<00:03,  2.45false/s, file=Log and Checkpoints/20
# Uploading:  92%|▉| 88/96 [00:45<00:08,  1.02s/false, file=Log and Checkpoints/20
# Uploading:  92%|▉| 88/96 [00:47<00:08,  1.02s/false, file=Log and Checkpoints/20
# Uploading:  93%|▉| 89/96 [00:47<00:08,  1.21s/false, file=Log and Checkpoints/20
# Uploading:  93%|▉| 89/96 [00:47<00:08,  1.21s/false, file=Log and Checkpoints/20
# Uploading:  94%|▉| 90/96 [00:47<00:05,  1.06false/s, file=Log and Checkpoints/20
# Uploading:  94%|▉| 90/96 [00:48<00:05,  1.06false/s, file=Log and Checkpoints/20
# Uploading:  95%|▉| 91/96 [00:48<00:04,  1.05false/s, file=Log and Checkpoints/20
# Uploading:  95%|▉| 91/96 [00:49<00:04,  1.05false/s, file=Log and Checkpoints/20
# Uploading:  96%|▉| 92/96 [00:49<00:03,  1.19false/s, file=Log and Checkpoints/20
# Uploading:  96%|▉| 92/96 [00:49<00:03,  1.19false/s, file=Log and Checkpoints/20
# Uploading:  97%|▉| 93/96 [00:50<00:02,  1.19false/s, file=Log and Checkpoints/20
# Uploading:  98%|▉| 94/96 [00:50<00:01,  1.63false/s, file=Log and Checkpoints/20
# Uploading:  98%|▉| 94/96 [00:50<00:01,  1.63false/s, file=Log and Checkpoints/20
# Uploading:  99%|▉| 95/96 [00:53<00:00,  1.63false/s, file=Log and Checkpoints/20
# Uploading: 100%|█| 96/96 [00:53<00:00,  1.11s/false, file=Log and Checkpoints/20
# Upload completed successfully!
